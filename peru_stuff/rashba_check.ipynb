# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import scipy.sparse as sp
import scipy.linalg as la

from matplotlib import pyplot as plt


from koala import pointsets
from koala.voronization import generate_lattice
from koala import graph_utils as gu


from tai_localizer.perulizer import (
    proximity_bonds,
    randomly_rotate,
    sigma_y,
    proximity_lattice,
    bhz_ham,
    bhz_trs_operator,
    z2_spec_loc,
)

from tai_localizer.lauralizer.amorphous_model_BHZ_2D import amorph_BHZ
from tai_localizer.lauralizer.localizer import (
    spectral_localizer_AII2D,
    pfaff_sign,
)

# %%
e, v = la.eigh(sigma_y)

a = v * np.sqrt(2)


a.T / a
# Out:
# array([[ 1.-0.j, -0.-1.j],
#        [ 0.+1.j,  1.-0.j]])

# %%
from jax.numpy import einsum
from scipy import linalg as la

A = np.random.random([4000, 4000])
B = np.random.random([4000, 4000])
C = np.random.random([4000, 4000])

# %%
# %time A@B@C
# %time einsum("ij,jk,kl -> il", A,B,C)
# Out:
# CPU times: user 962 ms, sys: 60.2 ms, total: 1.02 s
# Wall time: 533 ms
# CPU times: user 38.1 ms, sys: 87 ms, total: 125 ms
# Wall time: 53.7 ms
# Array([[1.9598586e+06, 1.9911174e+06, 1.9997795e+06, ..., 1.9663862e+06,
#         1.9657890e+06, 1.9934399e+06],
#        [1.9866619e+06, 2.0183215e+06, 2.0271120e+06, ..., 1.9931742e+06,
#         1.9928192e+06, 2.0205749e+06],
#        [1.9719929e+06, 2.0035230e+06, 2.0123076e+06, ..., 1.9783578e+06,
#         1.9781426e+06, 2.0057624e+06],
#        ...,
#        [1.9711746e+06, 2.0025439e+06, 2.0112014e+06, ..., 1.9776565e+06,
#         1.9771254e+06, 2.0048702e+06],
#        [1.9763264e+06, 2.0079956e+06, 2.0167192e+06, ..., 1.9828889e+06,
#         1.9825942e+06, 2.0103916e+06],
#        [1.9464608e+06, 1.9774991e+06, 1.9863679e+06, ..., 1.9530535e+06,
#         1.9525812e+06, 1.9796872e+06]], dtype=float32)
